# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# - 加载图像

# %%
img = cv2.imread("table.jpg")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
plt.show()

# %% [markdown]
# - 转为灰度图

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
rgb_gray_img = cv2.cvtColor(gray_img, cv2.COLOR_GRAY2RGB)
plt.imshow(rgb_gray_img)
plt.show()

# %% [markdown]
# - 初始化SIFT检测器对象并提取关键点

# %%
sift = cv2.xfeatures2d.SIFT_create()
keypoints = sift.detect(gray_img, None)

# %% [markdown]
# - 画出关键点

# %%
img_sift = np.copy(img)
cv2.drawKeypoints(img, keypoints, img_sift, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# Out:
# array([[[185, 217, 236],
#         [185, 217, 236],
#         [185, 217, 236],
#         ...,
#         [138, 149, 153],
#         [136, 147, 151],
#         [135, 146, 150]],
#
#        [[185, 217, 236],
#         [185, 217, 236],
#         [185, 217, 236],
#         ...,
#         [129, 150, 152],
#         [128, 149, 151],
#         [127, 148, 150]],
#
#        [[185, 217, 236],
#         [185, 217, 236],
#         [186, 218, 237],
#         ...,
#         [127, 151, 151],
#         [126, 150, 150],
#         [126, 150, 150]],
#
#        ...,
#
#        [[171, 205, 221],
#         [171, 205, 221],
#         [171, 204, 220],
#         ...,
#         [  6,  27,  35],
#         [  1,  17,  23],
#         [  6,  18,  24]],
#
#        [[171, 205, 221],
#         [171, 205, 221],
#         [172, 205, 221],
#         ...,
#         [  6,  20,  26],
#         [  2,  11,  15],
#         [ 18,  23,  26]],
#
#        [[170, 205, 219],
#         [171, 206, 220],
#         [173, 206, 221],
#         ...,
#         [  8,  17,  21],
#         [  4,   9,  12],
#         [ 26,  28,  29]]], dtype=uint8)

# %% [markdown]
# - 显示图像

# %%
rgb_img_sift = cv2.cvtColor(img_sift, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img_sift)
plt.show()
